# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("Messy_Teen_Mental_Health_Dataset.csv")

# %%
print(df.head(10))
# Out:
#         age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 0  17.00000  female                  4.542998      instagram      8.60000
# 1  18.00000  female                  4.542998         tiktok      5.00000
# 2  15.00000    male                  4.542998           both      4.50000
# 3  15.94614    male                  4.542998      instagram      6.44623
# 4  13.00000  female                  4.542998         tiktok      6.40000
# 5  15.94614    male                  4.542998         tiktok      6.44623
# 6  19.00000    male                  4.542998      instagram      7.60000
# 7  15.00000    male                  4.542998      instagram      6.80000
# 8  16.00000  female                  4.542998           both      4.10000
# 9  18.00000    male                  4.542998         tiktok      8.60000
#
#    screen_time_before_sleep  academic_performance  physical_activity  \
# 0                   1.74991              2.987693           0.400000
# 1                   1.74991              2.987693           1.100000
# 2                   1.74991              2.987693           1.700000
# 3                   1.74991              2.987693           1.010952
# 4                   1.74991              2.987693           1.900000
# 5                   1.74991              2.987693           1.010952
# 6                   1.74991              2.987693           1.500000
# 7                   1.74991              2.987693           1.900000
# 8                   1.74991              2.987693           1.100000
# 9                   1.74991              2.987693           1.600000
#
#   social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 0                     low       4.000000       7.000000         9.000000
# 1                    LOW        8.000000       8.000000         4.000000
# 2                    LOW       10.000000       2.000000         6.000000
# 3                    none       5.462298       5.605027         5.572711
# 4                  medium       8.000000       5.000000        10.000000
# 5                    LOW        5.462298       5.605027         5.572711
# 6                    high       4.000000       5.000000         8.000000
# 7                   NONE       10.000000       5.000000         5.000000
# 8                   HIGH        1.000000       6.000000         3.000000
# 9                   HIGH        1.000000      10.000000        10.000000
#
#    depression_label
# 0          0.000000
# 1          1.000000
# 2          0.000000
# 3          0.023339
# 4          0.000000
# 5          0.023339
# 6          0.000000
# 7          0.000000
# 8          0.000000
# 9          0.000000

# %%
print(df.tail(10))
# Out:
#        age  gender  daily_social_media_hours platform_usage  sleep_hours  \
# 1200  19.0  female                  4.542998           both          7.4
# 1201  13.0  female                  4.542998         tiktok          5.0
# 1202  18.0  female                  4.542998      instagram          7.7
# 1203  13.0  female                  4.542998           both          8.4
# 1204  13.0    male                  4.542998           both          5.8
# 1205  15.0    male                  4.542998      instagram          4.2
# 1206  16.0    male                  4.542998      instagram          8.3
# 1207  13.0    male                  4.542998           both          7.0
# 1208  15.0    male                  4.542998      instagram          7.3
# 1209  18.0  female                  4.542998           both          6.3
#
#       screen_time_before_sleep  academic_performance  physical_activity  \
# 1200                   1.74991              2.987693                1.4
# 1201                   1.74991              2.987693                1.8
# 1202                   1.74991              2.987693                1.2
# 1203                   1.74991              2.987693                0.1
# 1204                   1.74991              2.987693                1.9
# 1205                   1.74991              2.987693                0.4
# 1206                   1.74991              2.987693                1.6
# 1207                   1.74991              2.987693                1.4
# 1208                   1.74991              2.987693                1.4
# 1209                   1.74991              2.987693                0.5
#
#      social_interaction_level  stress_level  anxiety_level  addiction_level  \
# 1200                 MEDIUM             9.0            4.0              7.0
# 1201                   HIGH             4.0            9.0              2.0
# 1202                     low            3.0            1.0              2.0
# 1203                  medium            1.0            6.0              6.0
# 1204                    LOW             4.0            4.0             10.0
# 1205                    high            1.0            6.0              5.0
# 1206                  medium            4.0            8.0              5.0
# 1207                 MEDIUM             9.0           10.0              5.0
# 1208                   NONE            10.0            4.0              2.0
# 1209                 MEDIUM            10.0            1.0              8.0
#
#       depression_label
# 1200               0.0
# 1201               0.0
# 1202               0.0
# 1203               0.0
# 1204               0.0
# 1205               0.0
# 1206               0.0
# 1207               0.0
# 1208               0.0
# 1209               0.0

# %%
print(df.describe())
# Out:
#                age  daily_social_media_hours  sleep_hours  \
# count  1114.000000               1114.000000  1114.000000
# mean     15.946140                  4.542998     6.446230
# std       2.023396                  2.037323     1.450213
# min      13.000000                  1.000000     4.000000
# 25%      14.000000                  2.800000     5.200000
# 50%      16.000000                  4.500000     6.500000
# 75%      18.000000                  6.400000     7.600000
# max      19.000000                  8.000000     9.000000
#
#        screen_time_before_sleep  academic_performance  physical_activity  \
# count               1114.000000           1114.000000        1114.000000
# mean                   1.749910              2.987693           1.010952
# std                    0.716915              0.576926           0.579313
# min                    0.500000              2.000000           0.000000
# 25%                    1.100000              2.500000           0.500000
# 50%                    1.800000              2.980000           1.000000
# 75%                    2.400000              3.480000           1.500000
# max                    3.000000              4.000000           2.000000
#
#        stress_level  anxiety_level  addiction_level  depression_label
# count   1114.000000    1114.000000      1114.000000       1114.000000
# mean       5.462298       5.605027         5.572711          0.023339
# std        2.920774       2.858164         2.843098          0.151047
# min        1.000000       1.000000         1.000000          0.000000
# 25%        3.000000       3.000000         3.000000          0.000000
# 50%        5.000000       6.000000         6.000000          0.000000
# 75%        8.000000       8.000000         8.000000          0.000000
# max       10.000000      10.000000        10.000000          1.000000

# %%
print(df.info())
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1210 entries, 0 to 1209
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   age                       1114 non-null   float64
#  1   gender                    1210 non-null   str
#  2   daily_social_media_hours  1114 non-null   float64
#  3   platform_usage            1210 non-null   str
#  4   sleep_hours               1114 non-null   float64
#  5   screen_time_before_sleep  1114 non-null   float64
#  6   academic_performance      1114 non-null   float64
#  7   physical_activity         1114 non-null   float64
#  8   social_interaction_level  1210 non-null   str
#  9   stress_level              1114 non-null   float64
#  10  anxiety_level             1114 non-null   float64
#  11  addiction_level           1114 non-null   float64
#  12  depression_label          1114 non-null   float64
# dtypes: float64(10), str(3)
# memory usage: 123.0 KB
# None

# %%
print(pd.isnull(df).sum())
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64

# %%
# categorical data
df["gender"].unique()
df["gender"] = df["gender"].astype(str).str.strip().str.lower()
df["gender"] = df["gender"].replace(["none","null","nan"], np.nan)
df["gender"] = df["gender"].fillna(df["gender"].mode()[0])

# %%
df["platform_usage"] = df["platform_usage"].astype(str).str.strip().str.lower()
df["platform_usage"]= df["platform_usage"].replace(["none","null","nan"], np.nan)
df["platform_usage"]= df["platform_usage"].fillna(df["platform_usage"].mode()[0])

# %%
# Fill missing age values with the mean age
def clean_data(df):
    df["age"] = df["age"].fillna(df["age"].mean())
# fill missing values of sleep_hours with mean sleep_hours
    df["sleep_hours"] = df["sleep_hours"].fillna(df["sleep_hours"].mean())
# fill missing values
    df["depression_label"]= df["depression_label"].fillna(df["depression_label"].mean())
    df["addiction_level"]= df["addiction_level"].fillna(df["addiction_level"].mean())
    df["anxiety_level"]= df["anxiety_level"].fillna(df["anxiety_level"].mean())
    df["stress_level"]= df["stress_level"].fillna(df["stress_level"].mean())
    df["physical_activity"]= df["physical_activity"].fillna(df["physical_activity"].mean())
    df["academic_performance"]= df["academic_performance"].fillna(df["academic_performance"].mean())
    df["screen_time_before_sleep"]= df["screen_time_before_sleep"].fillna(df["screen_time_before_sleep"].mean())
    df["daily_social_media_hours"] = df["daily_social_media_hours"].fillna(df["daily_social_media_hours"].mean())
    return df

# %%
# Numpy is imported to calculate the average stress level
average_stress = np.mean(df["stress_level"])
if average_stress > 5:
    print("High Stress:",average_stress)
else:
    print("low stress:",average_stress)
# Out:
# High Stress: 5.46229802513465

# %%
print(df.isnull().sum())
# Out:
# age                         0
# gender                      0
# daily_social_media_hours    0
# platform_usage              0
# sleep_hours                 0
# screen_time_before_sleep    0
# academic_performance        0
# physical_activity           0
# social_interaction_level    0
# stress_level                0
# anxiety_level               0
# addiction_level             0
# depression_label            0
# dtype: int64

# %%
# Average stress level
print(df.groupby("gender")["stress_level"].mean())
# Out:
# gender
# female    5.429081
# male      5.488803
# Name: stress_level, dtype: float64

# %%
print(df.groupby("age")["stress_level"].mean())
# Out:
# age
# 13.00000    5.554945
# 14.00000    6.220690
# 15.00000    5.129630
# 15.94614    5.462298
# 16.00000    5.503268
# 17.00000    5.000000
# 18.00000    5.262821
# 19.00000    5.632258
# Name: stress_level, dtype: float64

# %%
print(df.groupby("daily_social_media_hours")["academic_performance"].mean())
# Out:
# daily_social_media_hours
# 4.542998    2.987693
# Name: academic_performance, dtype: float64

# %%
depressed = df[df["depression_label"] == 1]
print("Depressed Students:", len(depressed))
# Out:
# Depressed Students: 26

# %%
print("Maximum Stress:", df["stress_level"].max())
# Out:
# Maximum Stress: 10.0
